# %%
import cv2

# %%
import numpy as np

# %%
input = cv2.imread(r"C:\Users\santo\OneDrive\Desktop\Data science\Feb 2026\10th feb 2026\opencv\Elephant.jpg")

# %%
input
# Out:
# array([[[206, 152, 119],
#         [206, 152, 119],
#         [207, 153, 120],
#         ...,
#         [203, 149, 114],
#         [203, 149, 114],
#         [202, 148, 113]],
#
#        [[206, 152, 119],
#         [207, 153, 120],
#         [207, 153, 120],
#         ...,
#         [203, 149, 114],
#         [203, 149, 114],
#         [202, 148, 113]],
#
#        [[207, 153, 120],
#         [207, 153, 120],
#         [207, 153, 120],
#         ...,
#         [203, 149, 114],
#         [203, 149, 114],
#         [202, 148, 113]],
#
#        ...,
#
#        [[ 80, 146, 197],
#         [ 84, 150, 201],
#         [ 83, 149, 200],
#         ...,
#         [ 82, 143, 193],
#         [ 77, 138, 188],
#         [ 78, 139, 189]],
#
#        [[ 74, 140, 191],
#         [ 78, 144, 195],
#         [ 77, 143, 194],
#         ...,
#         [ 82, 143, 193],
#         [ 77, 138, 188],
#         [ 78, 139, 189]],
#
#        [[ 68, 134, 185],
#         [ 72, 138, 189],
#         [ 71, 137, 188],
# ...

# %%
import cv2

img = cv2.imread(r"C:\Users\santo\OneDrive\Desktop\Data science\Feb 2026\10th feb 2026\opencv\Elephant.jpg")   # put correct path here

if img is None:
    print("Image not found!")
else:
    cv2.imshow('Elephant', img)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# %%
print('Height of Image:', in(input.shape[0]), 'pixel')
print('Width of Image:', int(input.shape[1]), 'pixel')
# Out:
#   Cell In[4], line 1
#     print('Height of Image:', in(input.shape[0]), 'pixel')
#                               ^
# SyntaxError: invalid syntax

# %%
cv2.imwrite('output.png', input)

# %%
import os
os.getcwd()
