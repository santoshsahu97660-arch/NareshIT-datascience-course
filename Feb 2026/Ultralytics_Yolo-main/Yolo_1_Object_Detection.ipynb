# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.4.14  Python-3.13.5 torch-2.10.0+cpu CPU (12th Gen Intel Core i5-1235U)
# Setup complete  (12 CPUs, 7.7 GB RAM, 167.1/351.1 GB disk)

# %%
# Run inference on an image with YOLO11n
# !yolo predict model=yolo11n.pt source='https://ultralytics.com/images/zidane.jpg'
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo11n.pt to 'yolo11n.pt': 37% ━━━━──────── 2.0/5.4MB 20.0MB/s 0.1s<0.2s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo11n.pt to 'yolo11n.pt': 77% ━━━━━━━━━─── 4.1/5.4MB 21.3MB/s 0.2s<0.1s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo11n.pt to 'yolo11n.pt': 100% ━━━━━━━━━━━━ 5.4MB 20.9MB/s 0.3s
# Ultralytics 8.4.14  Python-3.13.5 torch-2.10.0+cpu CPU (12th Gen Intel Core i5-1235U)
# YOLO11n summary (fused): 100 layers, 2,616,248 parameters, 0 gradients, 6.5 GFLOPs
#
#
# Downloading https://ultralytics.com/images/zidane.jpg to 'zidane.jpg': 100% ━━━━━━━━━━━━ 49.2KB 4.9MB/s 0.0s
# image 1/1 c:\Users\santo\OneDrive\Desktop\Data science\Feb 2026\Ultralytics_Yolo-main\zidane.jpg: 384x640 2 persons, 1 tie, 113.9ms
# Speed: 9.1ms preprocess, 113.9ms inference, 14.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to C:\Users\santo\OneDrive\Desktop\Data science\Feb 2026\Ultralytics_Yolo-main\runs\detect\predict
#  Learn more at https://docs.ultralytics.com/modes/predict

# %%
# Run inference on an image with YOLO11n
# !yolo predict model=yolo11n.pt source='https://images.picxy.com/cache/2019/7/25/7cb6f63a656f23f38c4fff9a4cf219bc.jpg'
# Out:
# Ultralytics 8.4.14  Python-3.13.5 torch-2.10.0+cpu CPU (12th Gen Intel Core i5-1235U)
# YOLO11n summary (fused): 100 layers, 2,616,248 parameters, 0 gradients, 6.5 GFLOPs
#
#
# Downloading https://images.picxy.com/cache/2019/7/25/7cb6f63a656f23f38c4fff9a4cf219bc.jpg to '7cb6f63a656f23f38c4fff9a4cf219bc.jpg': 100% ━━━━━━━━━━━━ 419.9KB 11.4MB/s 0.0s
# image 1/1 c:\Users\santo\OneDrive\Desktop\Data science\Feb 2026\Ultralytics_Yolo-main\7cb6f63a656f23f38c4fff9a4cf219bc.jpg: 448x640 1 person, 1 cup, 1 chair, 2 laptops, 171.9ms
# Speed: 12.7ms preprocess, 171.9ms inference, 24.6ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to C:\Users\santo\OneDrive\Desktop\Data science\Feb 2026\Ultralytics_Yolo-main\runs\detect\predict2
#  Learn more at https://docs.ultralytics.com/modes/predict
