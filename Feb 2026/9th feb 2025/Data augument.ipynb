# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing.image import load_img, img_to_array

# %%
datagen = ImageDataGenerator(
    rotation_range=40,
    width_shift_range=0.4,
    height_shift_range=0.4,
    shear_range=0.4,
    zoom_range=0.4,
    horizontal_flip=True,
    rescale=None,
    fill_mode='wrap'  #nearest, reflect, wrap, constant
)

# load image from path

img = load_img(r"C:\Users\santo\OneDrive\Desktop\Data science\Feb 2026\9th feb 2025\momita.jpg")

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x900>

# %%
x = img_to_array(img)
x = x.reshape((1,) + x.shape) # Reshape to (1, height, width, channels)

for batch in datagen.flow(
        x,
        batch_size=1,
        save_to_dir=r"C:\Users\santo\OneDrive\Desktop\Data science\Feb 2026\9th feb 2025\DATA AUGUMENT",
        save_prefix='momita',
        save_format='jpeg'):  

    i += 1
    if i > 30:   # creates 30 images
        break
