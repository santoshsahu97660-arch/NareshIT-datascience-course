# %%
import numpy as np
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.metrics import classification_report
import warnings
warnings.filterwarnings('ignore')

# %%
# Step 1: Create an imbalanced binary classification dataset
X, y = make_classification(n_samples=1000, n_features=10, n_informative=2, n_redundant=8, 
                           weights=[0.9, 0.1], flip_y=0, random_state=42)

np.unique(y, return_counts=True)
# Out:
# (array([0, 1]), array([900, 100]))

# %%
# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, stratify=y, random_state=42)

# %%
log_reg = LogisticRegression(C=1, solver='liblinear')
log_reg.fit(X_train, y_train)
y_pred_log_reg = log_reg.predict(X_test)
print(classification_report(y_test, y_pred_log_reg))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.96      0.95       270
#            1       0.60      0.50      0.55        30
#
#     accuracy                           0.92       300
#    macro avg       0.77      0.73      0.75       300
# weighted avg       0.91      0.92      0.91       300

# %%
rf_clf = RandomForestClassifier(n_estimators=30, max_depth=3)
rf_clf.fit(X_train, y_train)
y_pred_rf = rf_clf.predict(X_test)
print(classification_report(y_test, y_pred_rf))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98       270
#            1       0.95      0.63      0.76        30
#
#     accuracy                           0.96       300
#    macro avg       0.96      0.81      0.87       300
# weighted avg       0.96      0.96      0.96       300

# %%
xgb_clf = XGBClassifier(use_label_encoder=False, eval_metric='logloss')
xgb_clf.fit(X_train, y_train)
y_pred_xgb = xgb_clf.predict(X_test)
print(classification_report(y_test, y_pred_xgb))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       270
#            1       0.96      0.80      0.87        30
#
#     accuracy                           0.98       300
#    macro avg       0.97      0.90      0.93       300
# weighted avg       0.98      0.98      0.98       300

# %%
from imblearn.combine import SMOTETomek

smt = SMOTETomek(random_state=0)
X_train_res, y_train_res = smt.fit_resample(X_train, y_train)

np.unique(y_train_res, return_counts=True)
# Out:
# (array([0, 1]), array([613, 613]))

# %%
xgb_clf = XGBClassifier(use_label_encoder=False, eval_metric='logloss')
xgb_clf.fit(X_train_res, y_train_res)
y_pred_xgb = xgb_clf.predict(X_test)
print(classification_report(y_test, y_pred_xgb))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.97      0.98       270
#            1       0.76      0.83      0.79        30
#
#     accuracy                           0.96       300
#    macro avg       0.87      0.90      0.88       300
# weighted avg       0.96      0.96      0.96       300

# %%
models = [
    (
        "Logistic Regression", 
        LogisticRegression(C=1, solver='liblinear'), 
        (X_train, y_train),
        (X_test, y_test)
    ),
    (
        "Random Forest", 
        RandomForestClassifier(n_estimators=30, max_depth=3), 
        (X_train, y_train),
        (X_test, y_test)
    ),
    (
        "XGBClassifier",
        XGBClassifier(use_label_encoder=False, eval_metric='logloss'), 
        (X_train, y_train),
        (X_test, y_test)
    ),
    (
        "XGBClassifier With SMOTE",
        XGBClassifier(use_label_encoder=False, eval_metric='logloss'), 
        (X_train_res, y_train_res),
        (X_test, y_test)
    )
]

# %%
reports = []

for model_name, model, train_set, test_set in models:
    X_train = train_set[0]
    y_train = train_set[1]
    X_test = test_set[0]
    y_test = test_set[1]
    
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    report = classification_report(y_test, y_pred, output_dict=True)
    reports.append(report)

# %%
import mlflow
import mlflow.sklearn
import mlflow.xgboost

# %%
# Initialize MLflow
mlflow.set_experiment("imbalanced classification")
mlflow.set_tracking_uri("http://localhost:5000")

for i, element in enumerate(models):
    model_name = element[0]
    model = element[1]
    report = reports[i]
    
    with mlflow.start_run(run_name=model_name):        
        mlflow.log_param("model", model_name)
        mlflow.log_metric('accuracy', report['accuracy'])
        mlflow.log_metric('recall_class_1', report['1']['recall'])
        mlflow.log_metric('recall_class_0', report['0']['recall'])
        mlflow.log_metric('f1_score_macro', report['macro avg']['f1-score'])        
        
        if "XGB" in model_name:
            mlflow.xgboost.log_model(model, "model")
        else:
            mlflow.sklearn.log_model(model, "model")
# Out:
# 2026/01/23 10:46:04 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2026/01/23 10:46:10 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 🏃 View run Logistic Regression at: http://localhost:5000/#/experiments/2/runs/33f0481804e3470693b81c32dfaa48e1
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# 2026/01/23 10:46:19 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 🏃 View run Random Forest at: http://localhost:5000/#/experiments/2/runs/366961d0570540b09e8c38c6e44da675
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# 🏃 View run XGBClassifier at: http://localhost:5000/#/experiments/2/runs/accf91eba691455a9236f924216ce24e
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 18
#      15 mlflow.log_metric('f1_score_macro', report['macro avg']['f1-score'])
#      17 if "XGB" in model_name:
# ---> 18     mlflow.xgboost.log_model(model, "model")
#      19 else:
#      20     mlflow.sklearn.log_model(model, "model")
#
# File c:\Users\santo\AppData\Local\Programs\Python\Python314\Lib\site-packages\mlflow\xgboost\__init__.py:283, in log_model(xgb_model, artifact_path, conda_env, code_paths, registered_model_name, signature, input_example, await_registration_for, pip_requirements, extra_pip_requirements, model_format, metadata, name, params, tags, model_type, step, model_id, **kwargs)
#     227 @format_docstring(LOG_MODEL_PARAM_DOCS.format(package_name=FLAVOR_NAME))
#     228 def log_model(
#     229     xgb_model,
#    (...)    247     **kwargs,
#     248 ):
#     249     """Log an XGBoost model as an MLflow artifact for the current run.
#     250
#     251     Args:
#    (...)    281         metadata of the logged model.
#     282     """
# --> 283     return Model.log(
#     284         artifact_path=artifact_path,
#     285         name=name,
#     286         flavor=mlflow.xgboost,
#     287         registered_model_name=registered_model_name,
#     288         xgb_model=xgb_model,
#     289         model_format=model_format,
#     290         conda_env=conda_env,
#     291         code_paths=code_paths,
#     292         signature=signature,
#     293         input_example=input_example,
#     294         await_registration_for=await_registration_for,
#     295         pip_requirements=pip_requirements,
#     296         extra_pip_requirements=extra_pip_requirements,
#     297         metadata=metadata,
#     298         params=params,
#     299         tags=tags,
#     300         model_type=model_type,
#     301         step=step,
#     302         model_id=model_id,
#     303         **kwargs,
#     304     )
#
# File c:\Users\santo\AppData\Local\Programs\Python\Python314\Lib\site-packages\mlflow\models\model.py:1209, in Model.log(cls, artifact_path, flavor, registered_model_name, await_registration_for, metadata, run_id, resources, auth_policy, prompts, name, model_type, params, tags, step, model_id, **kwargs)
#    1197     prompts = [pr.uri if isinstance(pr, PromptVersion) else pr for pr in prompts]
#    1199 mlflow_model = cls(
#    1200     artifact_path=model.artifact_location,
#    1201     model_uuid=model.model_id,
#    (...)   1207     model_id=model.model_id,
#    1208 )
# -> 1209 flavor.save_model(path=local_path, mlflow_model=mlflow_model, **kwargs)
#    1210 # `save_model` calls `load_model` to infer the model requirements, which may result
#    1211 # in __pycache__ directories being created in the model directory.
#    1212 for pycache in Path(local_path).rglob("__pycache__"):
#
# File c:\Users\santo\AppData\Local\Programs\Python\Python314\Lib\site-packages\mlflow\xgboost\__init__.py:171, in save_model(xgb_model, path, conda_env, code_paths, mlflow_model, signature, input_example, pip_requirements, extra_pip_requirements, model_format, metadata)
#     168 model_data_path = os.path.join(path, model_data_subpath)
#     170 # Save an XGBoost model
# --> 171 xgb_model.save_model(model_data_path)
#     172 xgb_model_class = _get_fully_qualified_class_name(xgb_model)
#     173 pyfunc.add_to_model(
#     174     mlflow_model,
#     175     loader_module="mlflow.xgboost",
#    (...)    179     code=code_dir_subpath,
#     180 )
#
# File c:\Users\santo\AppData\Local\Programs\Python\Python314\Lib\site-packages\xgboost\sklearn.py:1113, in XGBModel.save_model(self, fname)
#    1111 meta: Dict[str, Any] = {}
#    1112 # For validation.
# -> 1113 meta["_estimator_type"] = self._get_type()
#    1114 meta_str = json.dumps(meta)
#    1115 self.get_booster().set_attr(scikit_learn=meta_str)
#
# File c:\Users\santo\AppData\Local\Programs\Python\Python314\Lib\site-packages\xgboost\sklearn.py:1104, in XGBModel._get_type(self)
#    1102 def _get_type(self) -> str:
#    1103     if not hasattr(self, "_estimator_type"):
# -> 1104         raise TypeError(
#    1105             "`_estimator_type` undefined.  "
#    1106             "Please use appropriate mixin to define estimator type."
#    1107         )
#    1108     return self._estimator_type
#
# TypeError: `_estimator_type` undefined.  Please use appropriate mixin to define estimator type.
