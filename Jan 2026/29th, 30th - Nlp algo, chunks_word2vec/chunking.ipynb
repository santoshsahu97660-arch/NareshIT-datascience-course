# %%
pip install nltk
# Out:
# Collecting nltk
#   Using cached nltk-3.9.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting click (from nltk)
#   Using cached click-8.3.1-py3-none-any.whl.metadata (2.6 kB)
# Collecting joblib (from nltk)
#   Using cached joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting regex>=2021.8.3 (from nltk)
#   Using cached regex-2026.1.15-cp311-cp311-win_amd64.whl.metadata (41 kB)
# Collecting tqdm (from nltk)
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: colorama in c:\users\santo\appdata\roaming\python\python311\site-packages (from click->nltk) (0.4.6)
# Using cached nltk-3.9.2-py3-none-any.whl (1.5 MB)
# Using cached regex-2026.1.15-cp311-cp311-win_amd64.whl (277 kB)
# Using cached click-8.3.1-py3-none-any.whl (108 kB)
# Using cached joblib-1.5.3-py3-none-any.whl (309 kB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Installing collected packages: tqdm, regex, joblib, click, nltk
# Successfully installed click-8.3.1 joblib-1.5.3 nltk-3.9.2 regex-2026.1.15 tqdm-4.67.1
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script tqdm.exe is installed in 'c:\Users\santo\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script nltk.exe is installed in 'c:\Users\santo\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in c:\users\santo\appdata\local\programs\python\python311\lib\site-packages (24.0)
# Collecting pip
#   Using cached pip-25.3-py3-none-any.whl.metadata (4.7 kB)
# Using cached pip-25.3-py3-none-any.whl (1.8 MB)
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 24.0
#     Uninstalling pip-24.0:
#       Successfully uninstalled pip-24.0
# Successfully installed pip-25.3
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The scripts pip.exe, pip3.11.exe and pip3.exe are installed in 'c:\Users\santo\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
import nltk
from nltk import pos_tag, word_tokenize, RegexpParser

# Download necessary NLTK data files (only need to do this once)
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')

# Sample text
text = "full stack datasceince, generative ai, agenti ai, llm model keep increase by different compnay"

# Tokenize the text
tokens = word_tokenize(text)

# Perform part-of-speech tagging
tagged_tokens = pos_tag(tokens)

# Define a chunk grammar
chunk_grammar = r"""
  NP: {<DT>?<JJ>*<NN>}   # Noun Phrase
  VP: {<VB.*><NP|PP>*}    # Verb Phrase
  PP: {<IN><NP>}          # Prepositional Phrase
"""

# Create a chunk parser
chunk_parser = RegexpParser(chunk_grammar)

# Parse the tagged tokens
chunked = chunk_parser.parse(tagged_tokens)

# Print the chunked output
print(chunked)

# Optionally, you can visualize the chunks
chunked.draw()
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\santo\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\santo\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# (S
#   (NP full/JJ stack/NN)
#   (NP datasceince/NN)
#   ,/,
#   (NP generative/JJ ai/NN)
#   ,/,
#   (NP agenti/NN)
#   (NP ai/NN)
#   ,/,
#   (NP llm/JJ model/NN)
#   (VP keep/VB (NP increase/NN))
#   (PP by/IN (NP different/JJ compnay/NN)))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 34
#      31 print(chunked)
#      33 # Optionally, you can visualize the chunks
# ---> 34 chunked.draw()
#
# File c:\Users\santo\AppData\Local\Programs\Python\Python311\Lib\site-packages\nltk\tree\tree.py:761, in Tree.draw(self)
#     756 """
#     757 Open a new window containing a graphical diagram of this tree.
#     758 """
#     759 from nltk.draw.tree import draw_trees
# --> 761 draw_trees(self)
#
# File c:\Users\santo\AppData\Local\Programs\Python\Python311\Lib\site-packages\nltk\draw\tree.py:1008, in draw_trees(*trees)
#    1001 def draw_trees(*trees):
#    1002     """
#    1003     Open a new window containing a graphical diagram of the given
#    1004     trees.
#    1005
#    1006     :rtype: None
#    1007     """
# -> 1008     TreeView(*trees).mainloop()
#    1009     return
#
# File c:\Users\santo\AppData\Local\Programs\Python\Python311\Lib\site-packages\nltk\draw\tree.py:998, in TreeView.mainloop(self, *args, **kwargs)
#     996 if in_idle():
#     997     return
# --> 998 self._top.mainloop(*args, **kwargs)
#
# File c:\Users\santo\AppData\Local\Programs\Python\Python311\Lib\tkinter\__init__.py:1504, in Misc.mainloop(self, n)
#    1502 def mainloop(self, n=0):
#    1503     """Call the mainloop of Tk."""
# -> 1504     self.tk.mainloop(n)
#
# KeyboardInterrupt:
